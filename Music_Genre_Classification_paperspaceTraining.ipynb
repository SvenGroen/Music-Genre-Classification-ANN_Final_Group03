# %% [markdown]
# # Implementing ANN using Tensorflow - Final Project
# ## Using a Convolutional Neural Network for genre Classification in music
# ---
#
# by Group 03 - Lea Doppertin and Sven Groen
#
# We are trying to recreate the results achieved by:
#
# http://cs229.stanford.edu/proj2018/report/21.pdf
#
# ---

# %% [markdown]
# # Introduction

# %% [markdown]
# Here is a nice introduction about what we are doing

# %% [markdown]
# ## Related Work
#
# Here is some stuff that is related to our topic

# %% [markdown]
# ## Importing Librarys

# %%
import tensorflow as tf
import pandas as pd
import os
import numpy as np
# import librosa as lb
import matplotlib.pyplot as plt
import IPython.display as ipd
import random
from sklearn import preprocessing
from collections import defaultdict
# from librosa import display

# %%
random.seed(0)

# %% [markdown]
# # The raw Dataset

# %% [markdown]
# The GTZAN dataset was also used by Huang, Serafini and Pugh [1]. It consists of 1000 wav-audio files with each 30 secounds of length. They are sorted by musical genre.

# %% [markdown]
# ## Loading the Data in Python

# %% [markdown]
# ### creating a csv for easier use

# %% [markdown]
# Having the data in a Pandas Dataframe format makes it easier to access the files.

# %%
genre_directory = os.getcwd() + "/data/genres"

#get the labels (all Genres)
for dirpath, dirname, filename in os.walk(genre_directory):
    
    labels = dirname
    break

# creating touple dataset
data = []
for genre in labels:
    path = genre_directory + "\\" + genre
    for dirpath, dirnames, filenames in os.walk(path):
        for file in filenames:
            data.append((file,"data/genres/"+genre+"/"+file , genre))
            
#"data/genres/" + genre
# Out:
# /notebooks/data/genres

# %%
df = pd.DataFrame(data, columns = ["filename","path","genre"])
df.head()
# Out:
# Empty DataFrame
# Columns: [filename, path, genre]
# Index: []

# %%
print("Our Dataset consists of {} files.".format(len(df)))
print("The Genres are: {}".format(df.genre.unique()))
# Out:
# Our Dataset consists of 1000 files.
# The Genres are: ['blues' 'classical' 'country' 'disco' 'hiphop' 'jazz' 'metal' 'pop'
#  'reggae' 'rock']

# %% [markdown]
# ### example Datapoint

# %%
signals = []
sampling_rates=[]
for file in df["path"]:
    signal,sampling_rate= lb.load(file)
    signals.append(signal)
    sampling_rates.append(sampling_rate)

# %%
sampling_rates = set(sampling_rates)
print("The Sampling rate is equal across all audio files. It is: {}".format(sampling_rates))
# Out:
# The Sampling rate is equal across all audio files. It is: {22050}

# %%
# Lets hear a random example
ipd.Audio(np.random.choice(signals),rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Preprocessing

# %% [markdown]
# In [1] the Authors did some preprocessing to the audio in order to achieve better results:
#
# >"From each clip, we sampled a
# contiguous 2-second window at four random locations, thus augmenting our data to 8000 clips of two seconds each.
# Since this data was sampled at 22050HZ, this leaves us with 44100 features for the raw audio input. We restricted
# our windows to two seconds to limit the number of features. We found that 44100 features was the perfect balance
# between length of audio sample and dimension of feature space. Thus after pre-processing our input is of shape (8000,
# CS229 Final Report - Music Genre Classification
# 44100), where each feature denotes the amplitude at a certain timestep out of the 44100. We also used 100 samples of
# un-augmented data each of our cross validation and test sets."

# %% [markdown]
# ## 2-second random samples
#
# We need to sample contiguous 2-second window at four random locations.
# To get the duration of each signal in seconds we need to divide it by the sampling rate:

# %% [markdown]
# $\frac{len(signal)}{sampling\_rate} = duration_{sec.}$
#
# $\Leftrightarrow len(signal) = duration_{sec.} * sampling\_rate$

# %%
len_signal = 2 * sampling_rate
print("To receive 2 second random clips from our audio signal, we have to look at {} continous entries in our raw numpy signal.".format(len_signal))
# Out:
# To receive 2 second random clips from our audio signal, we have to look at 44100 continous entries in our raw numpy signal.

# %% [markdown]
# To achieve this we pick one random starting index (and make sure it can maximialy be at 28 seconds) and return the signal from that point on for 2 seconds:

# %%
# get a random starting point in the 30 sec. clip
def get_rand_sample(signal,duration,sr=22050):
    ''' samples a random part of a signal
    
    Parameters:
        signal (np.array): the signal from which a random sample should be drawn
        duration (int): how long the sample should be (in seconds)
    
    returns:
        np.array:  random part of signal of length duration (in seconds)
    
    '''
    
    len_signal=duration * sr
    rand_index = np.random.randint(len(signal)-len_signal+1,size=1)[0]
    
    return signal[rand_index: rand_index+len_signal]

# %% [markdown]
# ### Example

# %%
example = get_rand_sample(signals[np.random.randint(len(signals))],2,sr=sampling_rate)
assert(len(example)/sampling_rate==2.0)
ipd.Audio(example, rate=sampling_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Creating our training audio samples
#
# Now we need 4 of these 2 second samples for each file. We do this by calling our `get_rand_samples()` function 4 times.

# %%
data = defaultdict(list)

# for each .wav -file in our raw dataset
for i,file in enumerate(df["path"]):
    
    # load the signal and the sampling rate (sr is identical for all files)
    signal,sr = lb.load(file)
    # fill a dict. with the genres as key and list of 2 sec. samples from the audio files as values
    [data[df.iloc[i]["genre"]].append(get_rand_sample(signal=signal,duration=2,sr=sr)) for _ in range(4)] #get 4 samples

# %%
# since our raw dataset consisted of 1000 raw audio files from which we took 4 samples for each audio files we should have 4000 samples:
i=0
for genre in data:
    for entry in data[genre]:
        i+=1
assert i == len(df)*4

# %% [markdown]
# ## Mel-Spectograms
#
# The original authors converted the raw audio signal into mel-spectograms.
# To get the mel-spectogram we use librosas [melspectrogram()](https://librosa.github.io/librosa/generated/librosa.feature.melspectrogram.html) method
#
# When it comes to the parameters the authors say that they chose the following parameters:
# > 64 mel-bins and a window length of 512 samples with an
# overlap of 50% between windows. Based on previous academic success with such transformations, we then move to
# log-scaling using the formula $log(X^2)$.
#
# Moreover, the authors stated, that they converted the "raw" audio into mel-spectograms, we are sure they they refer to the 2 second random clips and not the 30 sec. clips. We assume this since the resulting spectogram which you will see below for 2 sec looks exactly like the authores showed in their paper. The "raw" 30 sec. melspectogram looks not like the spectograms in the paper, however, we will investigate these later on.

# %%
# Fixing parameters
N_MELS = 64
SR = sampling_rate
N_FFT = 512 # window length
HOP_LENGTH = N_FFT // 2 # "50% overlap between the windows"

# %%
# converts to log decibel
mel_log = lambda x: lb.power_to_db(x**2)

# %% [markdown]
# Let's look at one random example:

# %%
mel = lb.feature.melspectrogram(data["blues"][5],sr=SR,n_fft=N_FFT,hop_length=HOP_LENGTH,n_mels=N_MELS)

# %% [markdown]
# There are different approaches to visualize these mel-spectograms. Either Matplotlib [plt.imshow](https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.imshow.html) method (used by the authors) or librosa built in plotting function [specshow](https://librosa.github.io/librosa/generated/librosa.display.specshow.html#librosa.display.specshow). Below you can see how the log mel-spectograms differ:

# %%
plt.imshow(mel_log(mel))

# %%
lb.display.specshow(mel_log(mel))

# %% [markdown]
# The resulting Images are basically the same except that the [plt.imshow](https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.imshow.html) plots the image on a "upside down" y-axis (from 60 to 0).

# %% [markdown]
# ### creating the image dataset
#
# We decided to use the [plt.imshow](https://matplotlib.org/3.1.3/api/_as_gen/matplotlib.pyplot.imshow.html) method since it was also used by the authors. To create the dataset, we iterate through all files and save their respectve mel-spectogram images.

# %%
# saving the images

count=0 # used for naming the files

# storing path and labels as touples
data_images = []

# for genre in data:
for genre in labels:
    # for each entry in the dictionary
    for sample in data[genre]:
        # check if file already exists
        if not os.path.isfile("data/images/preprocessed/melspectogram_"+str(genre)+ "_" + str(count) +".png"):
            # extract the mel-feature, create the spectogram and save the image
            mel = lb.feature.melspectrogram(sample,sr=SR,n_fft=N_FFT,hop_length=HOP_LENGTH,n_mels=N_MELS)
            plt.imshow(mel_log(mel))
            plt.savefig("data/images/preprocessed/melspectogram_"+str(genre)+ "_" + str(count) +".png")
            
        # append the path of the saved files and the corresponding label (genre) as a tuple for later acces
        data_images.append(("\\data\\images\\preprocessed\\melspectogram_"+str(genre)+ "_" + str(count) +".png", genre))
        count +=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ce33a1d2b7cd> in <module>
#       9 for genre in labels:
#      10     # for each entry in the dictionary
# ---> 11     for sample in data[genre]:
#      12         # check if file already exists
#      13         if not os.path.isfile("data/images/preprocessed/melspectogram_"+str(genre)+ "_" + str(count) +".png"):
#
# TypeError: list indices must be integers or slices, not str

# %%
path = os.getcwd() + "/data/images/preprocessed"

img_list = []
genre_list=[]
img_tensor_list = []

for dirpath, dirnames, filenames in os.walk(path):
    for file in filenames:
        img=tf.io.read_file(path + "/" +file)
        
        s = file
        start = s.find('_')
        
        end = s[start+1:].find('_')
        
        genre= s[start+1:start+end+1]
        
        img=tf.image.decode_png(img,channels=3) #RGB only (no alpha levels)
        img = tf.image.convert_image_dtype(img, dtype=np.float32) # convert to float and normalize
        img_tensor_list.append(img)
        img = img.numpy()

        img_list.append(img)
        genre_list.append(genre)

# %% [markdown]
# ## One Hot Encode Labels
#
# Currently our Labels/Targets are just strings. We transfor it into a vector representation using a labelencoder and a One-Hot-Encoder to generate targets that can be used for machine learning.

# %%
genre_list = pd.DataFrame(genre_list)
lbl_enc = preprocessing.LabelEncoder()
genre_list=genre_list.apply(lbl_enc.fit_transform)
oh_enc = preprocessing.OneHotEncoder()
genre_list = oh_enc.fit_transform(genre_list).toarray()

# %% [markdown]
# ## Training and Test data
#
# With our preprocessing done, we can divide out Dataset into Training and Testing data. We used a 80:20 ratio of training:testing.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(img_list, genre_list, test_size=0.2)

# %%
print(genre_list.shape)
# Out:
# (1545, 10)

# %%
# transform into np.array()
X_train = np.array(X_train)
X_test = np.array(X_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# %%
img_tensor_list = tf.convert_to_tensor(img_tensor_list)
genre_list2 = tf.convert_to_tensor(genre_list)
X_train2, X_test2, y_train2, y_test2 = train_test_split(img_tensor_list, genre_list2, test_size=0.2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-6229e97d0032> in <module>
#       1 img_tensor_list = tf.convert_to_tensor(img_tensor_list)
#       2 genre_list2 = tf.convert_to_tensor(genre_list)
# ----> 3 X_train2, X_test2, y_train2, y_test2 = train_test_split(img_tensor_list, genre_list2, test_size=0.2)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2144
#    2145     return list(chain.from_iterable((_safe_indexing(a, train),
# -> 2146                                      _safe_indexing(a, test)) for a in arrays))
#    2147
#    2148
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py in <genexpr>(.0)
#    2144
#    2145     return list(chain.from_iterable((_safe_indexing(a, train),
# -> 2146                                      _safe_indexing(a, test)) for a in arrays))
#    2147
#    2148
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/__init__.py in _safe_indexing(X, indices, axis)
#     411         return _pandas_indexing(X, indices, indices_dtype, axis=axis)
#     412     elif hasattr(X, "shape"):
# --> 413         return _array_indexing(X, indices, indices_dtype, axis=axis)
#     414     else:
#     415         return _list_indexing(X, indices, indices_dtype)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/__init__.py in _array_indexing(array, key, key_dtype, axis)
#     197     if isinstance(key, tuple):
#     198         key = list(key)
# --> 199     return array[key] if axis == 0 else array[:, key]
#     200
#     201
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     775       new_axis_mask |= (1 << index)
#     776     else:
# --> 777       _check_index(s)
#     778       begin.append(s)
#     779       end.append(s + 1)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py in _check_index(idx)
#     664     # TODO(slebedev): IndexError seems more appropriate here, but it
#     665     # will break `_slice_helper` contract.
# --> 666     raise TypeError(_SLICE_TYPE_ERROR + ", got {!r}".format(idx))
#     667
#     668
#
# TypeError: Only integers, slices (`:`), ellipsis (`...`), tf.newaxis (`None`) and scalar tf.int32/tf.int64 tensors are valid indices, got array([ 629,  888, 1054, ...,  207,  592, 1400])

# %% [markdown]
# # The Convolutional Network

# %% [markdown]
# The authors provided a description of their neural network used:
#
# > " (...) using 3 convolution layers, each with its own max pool and regularization, feeding
# into 3 fully connected layers with ReLU activation, softmax output, and cross entropy loss. "

# %%
# defining the model

def cnn(input_shape, num_genres):
    inputs = tf.keras.layers.Input(shape=input_shape)
#     x = tf.keras.layers.Reshape(target_shape=input_shape)(inputs) # not necessary?
    # 1st Conv-Pool-layers
    x=inputs
    x = tf.keras.layers.Conv2D(filters=64, 
                               kernel_size=(4,4), 
                               activation=tf.keras.activations.relu)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPool2D(pool_size=(2,4))(x)
    # 2nd Conv-Pool-layers
    x = tf.keras.layers.Conv2D(filters=64, 
                               kernel_size=(3,5), 
                               activation=tf.keras.activations.relu,
                               kernel_regularizer=tf.keras.regularizers.l2(0.04))(x)
    x = tf.keras.layers.MaxPool2D(pool_size=(2,2))(x)
#     x = tf.keras.layers.Dropout(0.2)(x)
    # 3rd Conv-Pool-layers
    x = tf.keras.layers.Conv2D(filters=64, 
                               kernel_size=(2,2), 
                               activation=tf.keras.activations.relu)(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPool2D(pool_size=(2,2))(x)
#     x = tf.keras.layers.Dropout(0.2)(x)
    
    # Flatten before feeding into dense layers
    x = tf.keras.layers.Flatten()(x)
    
    # Dense layers
    x = tf.keras.layers.Dense(64,activation=tf.keras.activations.relu, kernel_regularizer=tf.keras.regularizers.l2(0.04))(x)
#     x = tf.keras.layers.Dropout(0.5)(x)
    x = tf.keras.layers.Dense(32,activation=tf.keras.activations.relu, kernel_regularizer=tf.keras.regularizers.l2(0.04))(x)
    
    # output layer
    output = tf.keras.layers.Dense(num_genres, activation=tf.keras.activations.softmax)(x)
    
    cnn_model = tf.keras.Model(inputs=inputs, outputs=output)
    return cnn_model

# %% [markdown]
# ## Training the model

# %% [markdown]
# ### setting the training parameters

# %%
batch_size = 32
sample_shape = tf.shape(X_train[0]).numpy()
input_shape = np.insert(sample_shape, 0, batch_size, axis=0)
optimizer = tf.keras.optimizers.Adam()
loss = tf.keras.losses.CategoricalCrossentropy()
accuracy = tf.keras.metrics.CategoricalAccuracy()


model = cnn(sample_shape, 10)

# %%
# compile the model
model.compile(optimizer, loss, metrics=[accuracy])

# %%
model.fit(X_train,y_train, batch_size=batch_size, epochs=100, validation_data=(X_test,y_test))
# Out:
# Train on 1236 samples, validate on 309 samples
# Epoch 1/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 1.1125 - categorical_accuracy: 0.8843 - val_loss: 1.8736 - val_categorical_accuracy: 0.6796
# Epoch 2/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.9972 - categorical_accuracy: 0.9070 - val_loss: 1.8260 - val_categorical_accuracy: 0.6764
# Epoch 3/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8912 - categorical_accuracy: 0.9256 - val_loss: 1.8981 - val_categorical_accuracy: 0.6343
# Epoch 4/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8952 - categorical_accuracy: 0.9223 - val_loss: 1.8616 - val_categorical_accuracy: 0.6667
# Epoch 5/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8398 - categorical_accuracy: 0.9337 - val_loss: 1.7724 - val_categorical_accuracy: 0.6861
# Epoch 6/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8352 - categorical_accuracy: 0.9296 - val_loss: 1.8707 - val_categorical_accuracy: 0.6893
# Epoch 7/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.7812 - categorical_accuracy: 0.9442 - val_loss: 1.8930 - val_categorical_accuracy: 0.6278
# Epoch 8/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8304 - categorical_accuracy: 0.9191 - val_loss: 2.6758 - val_categorical_accuracy: 0.5372
# Epoch 9/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.9473 - categorical_accuracy: 0.8859 - val_loss: 3.4125 - val_categorical_accuracy: 0.5728
# Epoch 10/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.9039 - categorical_accuracy: 0.9183 - val_loss: 2.1651 - val_categorical_accuracy: 0.6375
# Epoch 11/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.9112 - categorical_accuracy: 0.9215 - val_loss: 2.0008 - val_categorical_accuracy: 0.6731
# Epoch 12/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8511 - categorical_accuracy: 0.9337 - val_loss: 2.4675 - val_categorical_accuracy: 0.5566
# Epoch 13/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.7702 - categorical_accuracy: 0.9490 - val_loss: 1.9882 - val_categorical_accuracy: 0.6472
# Epoch 14/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6651 - categorical_accuracy: 0.9790 - val_loss: 1.6285 - val_categorical_accuracy: 0.7087
# Epoch 15/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5892 - categorical_accuracy: 0.9798 - val_loss: 1.6975 - val_categorical_accuracy: 0.6764
# Epoch 16/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5909 - categorical_accuracy: 0.9684 - val_loss: 1.7060 - val_categorical_accuracy: 0.6472
# Epoch 17/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5802 - categorical_accuracy: 0.9814 - val_loss: 1.8115 - val_categorical_accuracy: 0.6764
# Epoch 18/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5809 - categorical_accuracy: 0.9725 - val_loss: 2.0280 - val_categorical_accuracy: 0.6019
# Epoch 19/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6002 - categorical_accuracy: 0.9652 - val_loss: 2.1234 - val_categorical_accuracy: 0.6408
# Epoch 20/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6518 - categorical_accuracy: 0.9498 - val_loss: 2.5829 - val_categorical_accuracy: 0.6084
# Epoch 21/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.7324 - categorical_accuracy: 0.9474 - val_loss: 2.9202 - val_categorical_accuracy: 0.5631
# Epoch 22/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8526 - categorical_accuracy: 0.9159 - val_loss: 2.3819 - val_categorical_accuracy: 0.6311
# Epoch 23/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.9832 - categorical_accuracy: 0.8916 - val_loss: 2.4989 - val_categorical_accuracy: 0.6505
# Epoch 24/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8240 - categorical_accuracy: 0.9401 - val_loss: 2.3494 - val_categorical_accuracy: 0.6019
# Epoch 25/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8122 - categorical_accuracy: 0.9361 - val_loss: 2.3403 - val_categorical_accuracy: 0.6084
# Epoch 26/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.7458 - categorical_accuracy: 0.9644 - val_loss: 2.3832 - val_categorical_accuracy: 0.6861
# Epoch 27/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6325 - categorical_accuracy: 0.9838 - val_loss: 1.7897 - val_categorical_accuracy: 0.6958
# Epoch 28/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5162 - categorical_accuracy: 0.9968 - val_loss: 1.7135 - val_categorical_accuracy: 0.6861
# Epoch 29/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.4305 - categorical_accuracy: 0.9976 - val_loss: 1.5193 - val_categorical_accuracy: 0.6926
# Epoch 30/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3790 - categorical_accuracy: 1.0000 - val_loss: 1.4049 - val_categorical_accuracy: 0.6796
# Epoch 31/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3368 - categorical_accuracy: 1.0000 - val_loss: 1.3588 - val_categorical_accuracy: 0.6926
# Epoch 32/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3088 - categorical_accuracy: 0.9992 - val_loss: 1.3212 - val_categorical_accuracy: 0.6958
# Epoch 33/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2934 - categorical_accuracy: 1.0000 - val_loss: 1.3669 - val_categorical_accuracy: 0.6731
# Epoch 34/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3002 - categorical_accuracy: 0.9992 - val_loss: 1.3917 - val_categorical_accuracy: 0.6958
# Epoch 35/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3048 - categorical_accuracy: 0.9976 - val_loss: 1.4825 - val_categorical_accuracy: 0.7120
# Epoch 36/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3682 - categorical_accuracy: 0.9814 - val_loss: 1.7688 - val_categorical_accuracy: 0.6570
# Epoch 37/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.4863 - categorical_accuracy: 0.9595 - val_loss: 2.8490 - val_categorical_accuracy: 0.5566
# Epoch 38/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 1.0063 - categorical_accuracy: 0.8430 - val_loss: 4.1064 - val_categorical_accuracy: 0.5793
# Epoch 39/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 1.1286 - categorical_accuracy: 0.8665 - val_loss: 3.5420 - val_categorical_accuracy: 0.5793
# Epoch 40/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 1.0920 - categorical_accuracy: 0.8867 - val_loss: 2.6370 - val_categorical_accuracy: 0.6311
# Epoch 41/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8287 - categorical_accuracy: 0.9612 - val_loss: 2.3224 - val_categorical_accuracy: 0.6472
# Epoch 42/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6292 - categorical_accuracy: 0.9879 - val_loss: 2.0324 - val_categorical_accuracy: 0.6472
# Epoch 43/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.4998 - categorical_accuracy: 0.9943 - val_loss: 1.6628 - val_categorical_accuracy: 0.6602
# Epoch 44/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.4107 - categorical_accuracy: 0.9976 - val_loss: 1.6824 - val_categorical_accuracy: 0.6408
# Epoch 45/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3548 - categorical_accuracy: 0.9992 - val_loss: 1.5292 - val_categorical_accuracy: 0.6505
# Epoch 46/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3092 - categorical_accuracy: 0.9992 - val_loss: 1.4050 - val_categorical_accuracy: 0.6699
# Epoch 47/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3022 - categorical_accuracy: 0.9976 - val_loss: 1.4151 - val_categorical_accuracy: 0.6699
# Epoch 48/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2746 - categorical_accuracy: 0.9992 - val_loss: 1.4906 - val_categorical_accuracy: 0.6537
# Epoch 49/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2509 - categorical_accuracy: 0.9984 - val_loss: 1.4119 - val_categorical_accuracy: 0.6828
# Epoch 50/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2404 - categorical_accuracy: 1.0000 - val_loss: 1.3141 - val_categorical_accuracy: 0.7023
# Epoch 51/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2226 - categorical_accuracy: 0.9992 - val_loss: 1.2855 - val_categorical_accuracy: 0.6893
# Epoch 52/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2152 - categorical_accuracy: 0.9984 - val_loss: 1.3692 - val_categorical_accuracy: 0.6570
# Epoch 53/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2137 - categorical_accuracy: 1.0000 - val_loss: 1.3576 - val_categorical_accuracy: 0.6634
# Epoch 54/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2489 - categorical_accuracy: 0.9919 - val_loss: 1.6505 - val_categorical_accuracy: 0.7184
# Epoch 55/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.4107 - categorical_accuracy: 0.9515 - val_loss: 2.1008 - val_categorical_accuracy: 0.6149
# Epoch 56/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8309 - categorical_accuracy: 0.8794 - val_loss: 2.4729 - val_categorical_accuracy: 0.6764
# Epoch 57/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.9536 - categorical_accuracy: 0.8883 - val_loss: 3.1005 - val_categorical_accuracy: 0.6052
# Epoch 58/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8286 - categorical_accuracy: 0.9417 - val_loss: 2.9682 - val_categorical_accuracy: 0.6278
# Epoch 59/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6508 - categorical_accuracy: 0.9709 - val_loss: 2.2370 - val_categorical_accuracy: 0.6861
# Epoch 60/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5063 - categorical_accuracy: 0.9935 - val_loss: 1.8510 - val_categorical_accuracy: 0.6764
# Epoch 61/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3890 - categorical_accuracy: 0.9984 - val_loss: 1.7406 - val_categorical_accuracy: 0.6634
# Epoch 62/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3121 - categorical_accuracy: 0.9992 - val_loss: 1.5059 - val_categorical_accuracy: 0.6731
# Epoch 63/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2648 - categorical_accuracy: 1.0000 - val_loss: 1.3973 - val_categorical_accuracy: 0.6764
# Epoch 64/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2292 - categorical_accuracy: 1.0000 - val_loss: 1.3317 - val_categorical_accuracy: 0.6764
# Epoch 65/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2098 - categorical_accuracy: 1.0000 - val_loss: 1.3112 - val_categorical_accuracy: 0.6796
# Epoch 66/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1977 - categorical_accuracy: 1.0000 - val_loss: 1.3646 - val_categorical_accuracy: 0.6926
# Epoch 67/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1878 - categorical_accuracy: 1.0000 - val_loss: 1.2631 - val_categorical_accuracy: 0.6990
# Epoch 68/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1744 - categorical_accuracy: 0.9992 - val_loss: 1.1948 - val_categorical_accuracy: 0.6926
# Epoch 69/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1723 - categorical_accuracy: 0.9984 - val_loss: 1.3314 - val_categorical_accuracy: 0.6505
# Epoch 70/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2013 - categorical_accuracy: 0.9976 - val_loss: 1.5902 - val_categorical_accuracy: 0.6699
# Epoch 71/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2634 - categorical_accuracy: 0.9903 - val_loss: 1.6234 - val_categorical_accuracy: 0.6828
# Epoch 72/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6128 - categorical_accuracy: 0.9102 - val_loss: 3.1176 - val_categorical_accuracy: 0.6343
# Epoch 73/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8217 - categorical_accuracy: 0.9102 - val_loss: 3.6824 - val_categorical_accuracy: 0.5631
# Epoch 74/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.8493 - categorical_accuracy: 0.9159 - val_loss: 5.1738 - val_categorical_accuracy: 0.4757
# Epoch 75/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.7750 - categorical_accuracy: 0.9466 - val_loss: 2.2975 - val_categorical_accuracy: 0.6570
# Epoch 76/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6472 - categorical_accuracy: 0.9741 - val_loss: 2.4227 - val_categorical_accuracy: 0.6731
# Epoch 77/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5313 - categorical_accuracy: 0.9814 - val_loss: 2.1890 - val_categorical_accuracy: 0.6472
# Epoch 78/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.4429 - categorical_accuracy: 0.9903 - val_loss: 1.9096 - val_categorical_accuracy: 0.6861
# Epoch 79/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3545 - categorical_accuracy: 0.9968 - val_loss: 1.7106 - val_categorical_accuracy: 0.6505
# Epoch 80/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2870 - categorical_accuracy: 0.9992 - val_loss: 1.4934 - val_categorical_accuracy: 0.6796
# Epoch 81/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2398 - categorical_accuracy: 1.0000 - val_loss: 1.3914 - val_categorical_accuracy: 0.6796
# Epoch 82/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2059 - categorical_accuracy: 1.0000 - val_loss: 1.3510 - val_categorical_accuracy: 0.6796
# Epoch 83/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1829 - categorical_accuracy: 0.9992 - val_loss: 1.2483 - val_categorical_accuracy: 0.7023
# Epoch 84/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1689 - categorical_accuracy: 1.0000 - val_loss: 1.2602 - val_categorical_accuracy: 0.6699
# Epoch 85/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1554 - categorical_accuracy: 1.0000 - val_loss: 1.2605 - val_categorical_accuracy: 0.6796
# Epoch 86/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1465 - categorical_accuracy: 1.0000 - val_loss: 1.2266 - val_categorical_accuracy: 0.6926
# Epoch 87/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1392 - categorical_accuracy: 1.0000 - val_loss: 1.2342 - val_categorical_accuracy: 0.6764
# Epoch 88/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1348 - categorical_accuracy: 1.0000 - val_loss: 1.2391 - val_categorical_accuracy: 0.6731
# Epoch 89/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1309 - categorical_accuracy: 1.0000 - val_loss: 1.2017 - val_categorical_accuracy: 0.6796
# Epoch 90/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1282 - categorical_accuracy: 1.0000 - val_loss: 1.3099 - val_categorical_accuracy: 0.6958
# Epoch 91/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1378 - categorical_accuracy: 0.9992 - val_loss: 1.3369 - val_categorical_accuracy: 0.6990
# Epoch 92/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.1949 - categorical_accuracy: 0.9854 - val_loss: 2.0871 - val_categorical_accuracy: 0.6764
# Epoch 93/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6193 - categorical_accuracy: 0.9029 - val_loss: 3.0693 - val_categorical_accuracy: 0.6246
# Epoch 94/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 1.0735 - categorical_accuracy: 0.8560 - val_loss: 5.7880 - val_categorical_accuracy: 0.5210
# Epoch 95/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 1.0247 - categorical_accuracy: 0.8989 - val_loss: 3.1304 - val_categorical_accuracy: 0.6117
# Epoch 96/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.6882 - categorical_accuracy: 0.9636 - val_loss: 2.7793 - val_categorical_accuracy: 0.5955
# Epoch 97/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.5272 - categorical_accuracy: 0.9862 - val_loss: 1.8559 - val_categorical_accuracy: 0.6958
# Epoch 98/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.4340 - categorical_accuracy: 0.9919 - val_loss: 1.9396 - val_categorical_accuracy: 0.6828
# Epoch 99/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.3484 - categorical_accuracy: 0.9984 - val_loss: 1.5645 - val_categorical_accuracy: 0.6796
# Epoch 100/100
# 1236/1236 [==============================] - 14s 11ms/sample - loss: 0.2774 - categorical_accuracy: 0.9992 - val_loss: 1.5719 - val_categorical_accuracy: 0.6764

# %%
# save model
model.save('model_1.h5')

existing_model = keras.models.load_model('model_1.h5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-4a470722d6ab> in <module>
#       2 model.save('model_1.h5')
#       3
# ----> 4 existing_model = keras.models.load_model('model_1.h5')
#
# NameError: name 'keras' is not defined

# %%
model2 = cnn(sample_shape, len(labels))
# compile the model
model2.compile(optimizer, loss, metrics=[accuracy])

# %%
model.fit(X_train,y_train, batch_size=batch_size, epochs=1000, validation_data=(X_test,y_test))

# %% [markdown]
# # Performance

# %% [markdown]
# # Different approach
#
# There has been further development in the area of music genre classification, since the release of the paper we are replicating (2016). Therefore, we decided to have a look at the approach of a paper that has a similar approach towards the problem, but changes the network architecture and especially the preprocessing part [2].

# %% [markdown]
# ## Preprocessing
#
# Similiar to [1], [2] uses mel-spectograms to classify the audio tracks. Instead of sampling random 2-second audio snippets, [2] makes use of the whole 30 second audio clip by dividing it into 10 x 3 second audio snippets. The authors reason that it has been shown that human accuracy in this classification task plateus after 3 second.
#
# Again, the Librosa library is used to convert the audio into mel-spectograms. 23ms time windows and 50% overlab is used and afterwards log transformed

# %% [markdown]
# # Results

# %% [markdown]
# # References
#
# [1] http://cs229.stanford.edu/proj2018/report/21.pdf
#
# [2] https://arxiv.org/abs/1802.09697
